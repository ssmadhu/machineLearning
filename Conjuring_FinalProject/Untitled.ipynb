# %%
import pandas as pd
import numpy as np

# %%
col=['date','polarity','subjectivity','final','comments']

# %%
data=pd.read_csv("conjuringResults.csv", names=col)

# %%
data
# Out:
#             date     polarity  subjectivity  \
# 0           date     polarity  subjectivity
# 1      4/22/2021          0.1           0.3
# 2      4/22/2021        0.125             1
# 3      4/22/2021          0.2           0.1
# 4      4/22/2021         -0.2           0.8
# ...          ...          ...           ...
# 11000  7/12/2021         0.75           0.9
# 11001  7/12/2021  0.118055556   0.537962963
# 11002  7/13/2021            0             0
# 11003  7/13/2021            0             0
# 11004  7/13/2021      -0.3125        0.6875
#
#                                                 comments
# 0                                               comments
# 1       \u201cCongrats to Everyone who is early and w...
# 2                                                   Wow!
# 3       Zack Snyder fans: Nobody wants to know about ...
# 4                                                Oh shit
# ...                                                  ...
# ...

# %%
data.groupby(['date']).size
# Out:
# <bound method GroupBy.size of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0A6114A8>>

# %%
data.groupby(['date'])

# %%
data.groupby('date').count()
# Out:
#            polarity  subjectivity  comments
# date
# 4/22/2021      3267          3267      3267
# 4/23/2021      2696          2696      2695
# 4/24/2021      1708          1708      1708
# 4/25/2021       741           741       741
# 4/26/2021       399           399       399
# ...             ...           ...       ...
# 7/6/2021          6             6         6
# 7/7/2021          1             1         1
# 7/8/2021          5             5         5
# 7/9/2021          3             3         3
# date              1             1         1
#
# [84 rows x 3 columns]

# %%
data.groupby('date').count()
# Out:
#            polarity  subjectivity  comments
# date
# 4/22/2021      3267          3267      3267
# 4/23/2021      2696          2696      2695
# 4/24/2021      1708          1708      1708
# 4/25/2021       741           741       741
# 4/26/2021       399           399       399
# ...             ...           ...       ...
# 7/6/2021          6             6         6
# 7/7/2021          1             1         1
# 7/8/2021          5             5         5
# 7/9/2021          3             3         3
# date              1             1         1
#
# [84 rows x 3 columns]

# %%
data.groupby('date').mean()
# Out:
# Empty DataFrame
# Columns: []
# Index: [4/22/2021, 4/23/2021, 4/24/2021, 4/25/2021, 4/26/2021, 4/27/2021, 4/28/2021, 4/29/2021, 4/30/2021, 5/1/2021, 5/10/2021, 5/11/2021, 5/12/2021, 5/13/2021, 5/14/2021, 5/15/2021, 5/16/2021, 5/17/2021, 5/18/2021, 5/19/2021, 5/2/2021, 5/20/2021, 5/21/2021, 5/22/2021, 5/23/2021, 5/24/2021, 5/25/2021, 5/26/2021, 5/27/2021, 5/28/2021, 5/29/2021, 5/3/2021, 5/30/2021, 5/31/2021, 5/4/2021, 5/5/2021, 5/6/2021, 5/7/2021, 5/8/2021, 5/9/2021, 6/1/2021, 6/10/2021, 6/11/2021, 6/12/2021, 6/13/2021, 6/14/2021, 6/15/2021, 6/16/2021, 6/17/2021, 6/18/2021, 6/19/2021, 6/2/2021, 6/20/2021, 6/21/2021, 6/22/2021, 6/23/2021, 6/24/2021, 6/25/2021, 6/26/2021, 6/27/2021, 6/28/2021, 6/29/2021, 6/3/2021, 6/30/2021, 6/4/2021, 6/5/2021, 6/6/2021, 6/7/2021, 6/8/2021, 6/9/2021, 7/1/2021, 7/10/2021, 7/11/2021, 7/12/2021, 7/13/2021, 7/2/2021, 7/3/2021, 7/4/2021, 7/5/2021, 7/6/2021, 7/7/2021, 7/8/2021, 7/9/2021, date]
#
# [84 rows x 0 columns]

# %%
data.groupby('date').count()
# Out:
#            polarity  subjectivity  final  comments
# date
# 4/22/2021      3267          3267   3267      3267
# 4/23/2021      2696          2696   2696      2695
# 4/24/2021      1708          1708   1708      1708
# 4/25/2021       741           741    741       741
# 4/26/2021       399           399    399       399
# ...             ...           ...    ...       ...
# 7/6/2021          6             6      6         6
# 7/7/2021          1             1      1         1
# 7/8/2021          5             5      5         5
# 7/9/2021          3             3      3         3
# date              1             1      1         1
#
# [84 rows x 4 columns]

# %%
data.groupby('date').count()

# %%
data[['date','final']]
# Out:
#             date     final
# 0           date     Final
# 1      4/22/2021  POSITIVE
# 2      4/22/2021  POSITIVE
# 3      4/22/2021  POSITIVE
# 4      4/22/2021  NEGATIVE
# ...          ...       ...
# 11000  7/12/2021  POSITIVE
# 11001  7/12/2021  POSITIVE
# 11002  7/13/2021   NEUTRAL
# 11003  7/13/2021   NEUTRAL
# 11004  7/13/2021  NEGATIVE
#
# [11005 rows x 2 columns]

# %%
data[['date','final']].groupby('date').agg(['sum'])
# Out:
#                                                        final
#                                                          sum
# date
# 4/22/2021  POSITIVEPOSITIVEPOSITIVENEGATIVENEUTRALNEUTRAL...
# 4/23/2021  NEUTRALNEUTRALPOSITIVENEUTRALNEUTRALPOSITIVENE...
# 4/24/2021  POSITIVENEUTRALNEUTRALPOSITIVENEUTRALPOSITIVEP...
# 4/25/2021  NEUTRALNEGATIVENEUTRALPOSITIVENEUTRALNEUTRALNE...
# 4/26/2021  NEUTRALNEUTRALPOSITIVENEUTRALNEUTRALNEGATIVENE...
# ...                                                      ...
# 7/6/2021      NEGATIVEPOSITIVENEUTRALPOSITIVEPOSITIVENEUTRAL
# 7/7/2021                                            POSITIVE
# 7/8/2021                NEGATIVENEUTRALNEUTRALNEUTRALNEUTRAL
# 7/9/2021                             NEUTRALNEGATIVEPOSITIVE
# date                                                   Final
#
# [84 rows x 1 columns]

# %%
data[['date','final']].groupby('date').data['final'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-020b348a7667> in <module>
# ----> 1 data[['date','final']].groupby('date').data['final'].value_counts()
#
# c:\users\ssmad\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     908             return self[attr]
#     909
# --> 910         raise AttributeError(
#     911             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     912         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'data'

# %%
data[['date','final']].groupby('date').count()
# Out:
#            final
# date
# 4/22/2021   3267
# 4/23/2021   2696
# 4/24/2021   1708
# 4/25/2021    741
# 4/26/2021    399
# ...          ...
# 7/6/2021       6
# 7/7/2021       1
# 7/8/2021       5
# 7/9/2021       3
# date           1
#
# [84 rows x 1 columns]

# %%
data[['date','final']].groupby('date').value_counts().POSITIVE
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-07cc3462f46c> in <module>
# ----> 1 data[['date','final']].groupby('date').value_counts().POSITIVE
#
# c:\users\ssmad\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     908             return self[attr]
#     909
# --> 910         raise AttributeError(
#     911             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     912         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'value_counts'

# %%
data.value_counts(data[['date','final']].groupby('date'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-4eaf8006499a> in <module>
# ----> 1 data.value_counts(data[['date','final']].groupby('date'))
#
# c:\users\ssmad\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in value_counts(self, subset, normalize, sort, ascending, dropna)
#    6509             subset = self.columns.tolist()
#    6510
# -> 6511         counts = self.groupby(subset, dropna=dropna).grouper.size()
#    6512
#    6513         if sort:
#
# c:\users\ssmad\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7624         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7625         # "Union[bool, NoDefault]"; expected "bool"
# -> 7626         return DataFrameGroupBy(
# ...
